# %%
import pandas as pd  #libraries imported
import numpy as np
from matplotlib import pyplot as plt

# %%
coffee_production = pd.read_csv('C:\\Users\\sreek\\OneDrive\\Desktop\\coffee_data\\total-production.csv').T #for reading file
coffee_production.columns = coffee_production.iloc[0] #Selects the first row of the transposed DataFrame.Sets the first row as the new column names.
coffee_production = coffee_production.drop('total_production') #drop
coffee_production.head() #To quickly preview the data.
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# 1991                      746.816   79.653  ...  192.532       54.379
# 1992                      900.111   54.291  ...  196.978       39.084
# 1993                     1019.481   70.046  ...  142.066       37.451
# 1994                     1138.659   24.689  ...  248.313       72.738
#
# total_production Sri Lanka  Thailand     Togo Trinidad & Tobago    Uganda  \
# 1990                 95.87   757.017  161.308            14.581  1955.009
# 1991                81.549  1468.936  432.652            17.792  2088.001
# 1992                53.181  1254.945   85.648            14.328  2185.074
# 1993                 53.79  1275.201  194.939            16.079  3141.706
# 1994                42.448  1399.135  176.296            18.435  2392.753
#
# total_production Venezuela  Viet Nam Yemen
# 1990              1122.477  1310.288   0.0
# 1991               940.704  1437.848   0.0
# 1992              1215.298  2340.447   0.0
# 1993              1332.881  3020.216   0.0
# 1994               988.996  3631.609   0.0
#
# [5 rows x 56 columns]

# %%
top10_producers = coffee_production.sum().sort_values(ascending = False).iloc[:10] #top 10 will took
top10_producers
# Out:
# total_production
# Brazil       1190965.7353
# Viet Nam      439540.9519
# Colombia      345871.4464
# Indonesia     245116.7707
# Ethiopia      141542.8931
# India          132025.681
# Mexico        126908.2467
# Guatemala     113401.0702
# Honduras      105456.5888
# Uganda          93146.369
# dtype: object

# %%
#figsize=(8,4) sets the size of the figure to 8 inches wide and 4 inches tall.figure and axes
fig, ax = plt.subplots(figsize=(8,4))


ax.bar(top10_producers.index, top10_producers.values/1_000_000, width = .6, color = 'orange')#Creates a bar chart.

# top10_producers.index: The country names or codes.

# top10_producers.values/1_000_000: Scales values to millions of 60kg bags.

# width = .6: Sets bar width.

# color = 'orange': Sets bar color.

positions = list(range(10))
labels = ["BR", "VN", "CO", "ID", "ET", "IN", "MX", "GT", "HN", "UG"]

ax.set_title('Top Coffee Producing Nations 1990-2018')
ax.set_ylabel('Production (Millions 60kg Bags)', fontsize=12)

ax.set_xticks(positions) #Sets x-axis tick positions.

#Replaces default country names with short custom labels (like BR, VN, etc.).
ax.set_xticklabels(labels)

ax.spines['top'].set_visible(False) #Removes the top and right borders (spines) for a cleaner look.
ax.spines['right'].set_visible(False)

plt.show()

# %%
top5 = coffee_production.loc[:, ['Brazil', 'Viet Nam', 'Colombia', 'Indonesia', 'Ethiopia']]
top5.index = top5.index.astype('datetime64[ns]')

top5.head().round()
# Out:
# total_production      Brazil  Viet Nam   Colombia Indonesia  Ethiopia
# 1990-01-01        27285.6286  1310.288    14396.0  7441.383  2909.451
# 1991-01-01        27293.4934  1437.848  17980.397  8493.196  2924.664
# 1992-01-01        34603.3542  2340.447  14946.878  5569.478  1825.171
# 1993-01-01        28166.9786  3020.216  11422.422  6743.288  2967.004
# 1994-01-01         28192.047  3631.609    12964.0  5367.878   2762.73

# %%
fig, ax = plt.subplots()

ax.plot(top5/1_000)

ax.set_title('Top Coffee Producing Nations 1990-2018')
ax.set_ylabel('Production (Thousands 60kg Bags)', fontsize = 12)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.legend(top5.columns, frameon = False, bbox_to_anchor = (1.1, 1))
plt.show()

# %%
coffee_production.head()
# Out:
# total_production  Angola Bolivia (Plurinational State of)      Brazil  \
# 1990              50.345                          122.777  27285.6286
# 1991              79.331                          103.536  27293.4934
# 1992               77.52                          120.235  34603.3542
# 1993              32.608                           50.823  28166.9786
# 1994              76.802                          116.944   28192.047
#
# total_production  Burundi   Ecuador Indonesia Madagascar   Malawi  \
# 1990              487.393  1503.815  7441.383    982.447  104.628
# 1991              667.199  2123.824  8493.196    932.513  124.286
# 1992              620.238   1185.48  5569.478   1121.684  137.161
# 1993              393.354  2069.007  6743.288    441.859   62.111
# 1994              664.143  2375.766  5367.878    641.372   84.112
#
# total_production Papua New Guinea Paraguay  ...   Panama Sierra Leone  \
# 1990                      962.841  130.627  ...  214.987       42.783
# 1991                      746.816   79.653  ...  192.532       54.379
# 1992                      900.111   54.291  ...  196.978       39.084
# 1993                     1019.481   70.046  ...  142.066       37.451
# 1994                     1138.659   24.689  ...  248.313       72.738
#
# total_production Sri Lanka  Thailand     Togo Trinidad & Tobago    Uganda  \
# 1990                 95.87   757.017  161.308            14.581  1955.009
# 1991                81.549  1468.936  432.652            17.792  2088.001
# 1992                53.181  1254.945   85.648            14.328  2185.074
# 1993                 53.79  1275.201  194.939            16.079  3141.706
# 1994                42.448  1399.135  176.296            18.435  2392.753
#
# total_production Venezuela  Viet Nam Yemen
# 1990              1122.477  1310.288   0.0
# 1991               940.704  1437.848   0.0
# 1992              1215.298  2340.447   0.0
# 1993              1332.881  3020.216   0.0
# 1994               988.996  3631.609   0.0
#
# [5 rows x 56 columns]

# %%
brazil_vs_others = (
                        coffee_production
                        .assign(rest_of_the_world = coffee_production
                                .drop('Brazil', axis = 1).sum(axis = 1))
                        .loc[:, ['Brazil', 'rest_of_the_world']]
                        .astype({'Brazil': 'float64', 'rest_of_the_world': 'float64'})
                    )

brazil_vs_others.head()
# Out:
# total_production      Brazil  rest_of_the_world
# 1990              27285.6286          65944.431
# 1991              27293.4934          73973.191
# 1992              34603.3542          63922.545
# 1993              28166.9786          63597.643
# 1994              28192.0470          65121.147

# %%
fig, ax = plt.subplots()

ax.stackplot(
    brazil_vs_others.index.astype('datetime64[ns]'),
    brazil_vs_others['Brazil'],
    brazil_vs_others["rest_of_the_world"],
    labels = ['Brazil', 'World Total'],
    colors=['green', 'aqua'],
    edgecolor = 'white'
)

#

ax.set_title("Brazil's Share of Global Coffee Production 1990-2018")
ax.set_ylabel('Production (60kg Bags)', fontsize= 12)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.legend(frameon = False, loc = 'upper left')
plt.show()

# %%
fig, ax = plt.subplots(figsize = (6,4))

ax.scatter(
    coffee_production['Brazil'],
    coffee_production['Viet Nam'],
    color = 'red'
)

ax.set_title('Brazil vs. Viet Nam Production 1990-2018')
ax.set_ylabel('Viet Name Production (Millions 60kg Bags)', fontsize=11)
ax.set_xlabel('Brazil Production (Millions 60kg Bags)', fontsize=11)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,4))

ax.scatter(
    coffee_production['Brazil'],
    coffee_production['Venezuela'],
    color = 'green'
)

ax.set_title('Brazil vs. Venezuela Production 1990-2018')
ax.set_xlabel('Brazil Production (Millions 60kg Bags)', fontsize=11)
ax.set_ylabel('Venezuela Production (Millions 60kg Bags)', fontsize=11)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.show()

# %%
coffee_production['Rest_of_World'] = (
    coffee_production.drop(
    ['Brazil', 'Viet Nam', 'Colombia', 'Indonesia', 'Ethiopia',], axis = 1).sum(axis=1)
)

coffee_production_top5_2018 = (
    coffee_production
    .loc['2018',
        ['Brazil', 'Viet Nam', 'Colombia', 'Indonesia', 'Ethiopia', 'Rest_of_World']
        ]
)

coffee_production_top5_2018
# Out:
# total_production
# Brazil           62924.8836
# Viet Nam         31174.0742
# Colombia          13857.962
# Indonesia         9417.5942
# Ethiopia          7776.2234
# Rest_of_World    45786.0003
# Name: 2018, dtype: object

# %%
fig, ax = plt.subplots()

ax.pie(
    coffee_production_top5_2018[::-1], 
    labels = coffee_production_top5_2018.index[::-1],
    autopct="%.0f%%",
    pctdistance = .80,
    startangle=90
)
ax.set_title('Share of Global Coffee Production 2018')

plt.show()

# %%
brazil_vs_others = (
    coffee_production
    .assign(others = coffee_production.drop('Brazil', axis = 1).sum(axis = 1))
    .loc[:, ['Brazil', 'others']]
    .astype({'Brazil': 'float64', 'others': 'float64'})
        
    )

brazil_vs_others
# Out:
# total_production      Brazil       others
# 1990              27285.6286  105831.7400
# 1991              27293.4934  117110.2770
# 1992              34603.3542  103163.1160
# 1993              28166.9786  103042.3560
# 1994              28192.0470  105516.0770
# 1995              18060.2022  113867.6570
# 1996              29196.7430  120052.3490
# 1997              26148.0040  117647.3100
# 1998              36760.8533  116119.3556
# 1999              47577.8065  136127.7035
# 2000              31310.3530  129450.1897
# 2001              31365.0955  117146.9388
# 2002              48351.6340  114417.1028
# 2003              28873.4093  116079.0318
# 2004              39281.1457  115020.5696
# 2005              32932.9797  116742.7318
# 2006              48431.7338  129380.4618
# 2007              38911.4571  123198.5739
# 2008              51490.5177  124954.6093
# 2009              43976.8120  123760.2051
# 2010              55428.4102  128026.6989
# 2011              48591.8289  139926.8397
# 2012              55418.0012  139100.9264
# 2013              54688.9664  139750.4520
# 2014              53304.7669  135541.8274
# 2015              52870.5876  140189.2886
# 2016              56788.1784  147242.0413
# 2017              52739.8635  150650.8649
# 2018              62924.8836  153797.8544

# %%
fig, ax = plt.subplots(figsize = (4,4))

ax.pie(
    brazil_vs_others.loc['1990'].sort_values(ascending=False),
    startangle = 90,
    labels = ['', ''],
    colors = ['lightgreen', 'green']
)

hole = plt.Circle((0,0), 0.70, fc='white')

fig = plt.gcf()
fig.gca().add_artist(hole)

plt.text(
    0,
    0,
    f"{round((brazil_vs_others.loc['1990', 'Brazil'] / brazil_vs_others.loc['1990'].sum() * 100 ))}%",
    ha = 'center',
    va = 'center',
    fontsize = 42
)

ax.set_title('Brazil Share of Global Production 1990', fontsize = 14)

plt.show()

# %%
fig, ax = plt.subplots(figsize = (4,4))

ax.pie(
    brazil_vs_others.loc['2018'].sort_values(ascending=False),
    startangle = 90,
    labels = ['', ''],
    colors = ['lightcoral', 'red']
)

hole = plt.Circle((0,0), 0.70, fc='white')

fig = plt.gcf()
fig.gca().add_artist(hole)

plt.text(
    0,
    0,
    f"{round((brazil_vs_others.loc['2018', 'Brazil'] / brazil_vs_others.loc['2018'].sum() * 100 ))}%",
    ha = 'center',
    va = 'center',
    fontsize = 42
)

ax.set_title('Brazil Share of Global Production 2018', fontsize = 14)

plt.show()

# %%
imports = pd.read_csv(r'C:\Users\sreek\Downloads\Data-Analysis-Projects-main\Data-Analysis-Projects-main\3 - Coffee Production and Price Analysis\Data\imports.csv')
imports.head()
# Out:
#                  imports    1990    1991    1992    1993    1994    1995  \
# 0                Austria  1880.0  2058.0  2206.0  1836.0  1417.0  1231.0
# 1                Belgium     NaN     NaN     NaN     NaN     NaN     NaN
# 2     Belgium/Luxembourg  2015.0  1746.0  1828.0  2063.0  2262.0  2401.0
# 3               Bulgaria   268.0   200.0   182.0   397.0   463.0   515.0
# 4                Croatia     NaN     NaN   168.0   163.0   193.0   320.0
#
#      1996    1997    1998  ...    2009    2010    2011    2012    2013  2014  \
# 0  1210.0  1294.0  1293.0  ...  1309.0  1369.0  1452.0  1559.0  1555.0   NaN
# 1     NaN     NaN     NaN  ...  5916.0  5924.0  5828.0  5668.0  5502.0   NaN
# 2  2526.0  2544.0  3580.0  ...     NaN     NaN     NaN     NaN     NaN   NaN
# 3   272.0   294.0   342.0  ...   523.0   528.0   482.0   560.0   609.0   NaN
# 4   322.0   385.0   339.0  ...   394.0   394.0   391.0   384.0   413.0   NaN
#
#    2015  2016  2017  2018
# 0   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN
#
# [5 rows x 30 columns]

# %%
consumption = pd.read_csv(r'C:\Users\sreek\Downloads\Data-Analysis-Projects-main\Data-Analysis-Projects-main\3 - Coffee Production and Price Analysis\Data\imports.csv').set_index('imports').mean(axis = 1)
consumption.name = 'imports'

consumption
# Out:
# imports
#    Austria               1551.083333
#    Belgium               4639.533333
#    Belgium/Luxembourg    2329.444444
#    Bulgaria               397.250000
#    Croatia                349.136364
#                             ...
# South America             949.063449
# Argentina                 626.416914
# Chile                     261.124677
# Suriname                   11.614819
# Uruguay                    49.941523
# Name: imports, Length: 147, dtype: float64

# %%
prices = pd.read_csv(r"C:\Users\sreek\Downloads\Data-Analysis-Projects-main\Data-Analysis-Projects-main\3 - Coffee Production and Price Analysis\Data\retail-prices.csv")
prices.head()
# Out:
#   retail_prices       1990       1991       1992       1993       1994  \
# 0       Austria  10.816777  10.088300  11.015453  10.971302  10.110375
# 1        Cyprus   6.247241   6.181015   6.335541   5.739514   7.019868
# 2       Denmark   8.410596   8.101545   8.366446   7.682119   9.823400
# 3       Finland   6.578366   6.004415   5.430464   4.282561   6.026490
# 4        France   8.233996   7.571744   5.099338   4.481236   5.298013
#
#         1995       1996       1997       1998  ...       2009       2010  \
# 0  11.434879  11.964680   9.646799   8.763797  ...  15.342163  14.768212
# 1   9.403974   9.116998   8.918322  10.176600  ...  12.207506  11.501104
# 2  12.295806  10.618102  10.949227  10.860927  ...  11.677704  12.008830
# 3   8.763797   7.108168   7.726269   7.549669  ...   7.748344   8.145695
# 4   8.145695   7.284768   6.092715   6.136865  ...   8.366446   7.991170
#
#         2011       2012       2013       2014       2015       2016  \
# 0  18.366446  18.498896  19.028698  19.050773  16.423841  12.450331
# 1  13.377483  14.039735  14.282561  14.304636  11.699779  11.699779
# 2  15.275938  14.834437  14.039735  14.194260  12.913907  10.905077
# 3  11.832230  10.596026   9.470199   9.514349   8.609272   8.101545
# 4   9.116998   8.653422   8.653422   8.322296   6.865342   7.196468
#
#         2017       2018
# 0  13.730684  14.635762
# 1  12.141280  12.781457
# 2  11.103753  11.699779
# 3   9.050773   9.359823
# 4   7.505519   8.123620
#
# [5 rows x 30 columns]

# %%
prices = pd.read_csv(r"C:\Users\sreek\Downloads\Data-Analysis-Projects-main\Data-Analysis-Projects-main\3 - Coffee Production and Price Analysis\Data\retail-prices.csv").set_index('retail_prices').mean(axis=1)
prices.head()
# Out:
# retail_prices
# Austria    11.571135
# Cyprus     10.437695
# Denmark    10.494025
# Finland     7.211692
# France      6.850879
# dtype: float64

# %%
price_cons = (
    pd.DataFrame(prices)
    .merge(
        consumption,
        left_on = prices.index,
        right_on = consumption.index,
        how = 'inner'
    )
    .sort_values(['imports'], ascending = False)
)

price_cons.columns = ['Country', 'Prices', 'Imports']

price_cons['Country'] = price_cons['Country'].str.strip(' ')
price_cons
# Out:
#         Country     Prices       Imports
# 5       Germany   9.515110  16357.666667
# 11        Japan  21.472939   6862.275235
# 6         Italy  14.199589   6696.958333
# 4        France   6.850879   6512.458333
# 9         Spain   8.029992   4046.291667
# 7   Netherlands   8.931263   2928.125000
# 10       Sweden   8.054350   1620.625000
# 0       Austria  11.571135   1551.083333
# 3       Finland   7.211692   1157.541667
# 2       Denmark  10.494025    991.791667
# 8      Portugal  10.921063    810.791667
# 12       Norway   9.409302    739.770359
# 1        Cyprus  10.437695     63.791667

# %%
fig, ax = plt.subplots(figsize = (14,6))

width = 0.35
x = np.arange(len(price_cons['Country']))

bar1 = ax.bar(
    x - width/2,
    price_cons['Imports'],
    width = width
)

ax.set_title('Prices Paid Vs. Consumption of Select Importing Nations', fontsize = 18, fontweight = 'bold')
ax.set_ylabel('Consumption (k 60kgs bags)', fontsize = 12)

ax2 = ax.twinx()

bar2 = ax2.bar(
    x + width/2, 
    price_cons['Prices'],
    width = width,
    color = 'orange'
)

ax2.set_ylabel('Average Price Paid Per Bag (USD)', fontsize = 12)

plt.xticks(x, price_cons['Country'], fontsize = 7)

ax.legend([bar1, bar2], ['Consumption', 'Prices'], frameon = False)

plt.show()

# %%
cd C:\\Users\\sreek\\Downloads\\coffee_production_analysis
# Out:
# [WinError 2] The system cannot find the file specified: 'C:\\\\Users\\\\sreek\\\\Downloads\\\\coffee_production_analysis'
# C:\Users\sreek\Downloads
